# %%
import sys
if '/home/nwest13/twitter/zhenning/Content_Analysis/NN' not in sys.path:
    sys.path.insert(0, '/home/nwest13/twitter/zhenning/Content_Analysis/NN')
import nn
from nn import keras_model

import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
model = nn.load_pkl('../../../Zach/Relevance/best_lstm_so_far_88_81.pkl')
# Out:
# ---------------------
# loading
# ---------------------
# ../../../Zach/Relevance/best_lstm_so_far_88_81.pkl load

# %%
model.infor()
# Out:
# Model version: 6.0
# ...
# Detected labels:   [0 1]
# test_split:        separate validation data
# valid data labels: [0 1]
# num_words:         1193513
# maxlen:            99
# Learning_Rate(lr): 0.01
# loss function:     binary_crossentropy
# ...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_2 (Embedding)      (None, 99, 200)           238702600
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 99, 10)            8440
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 990)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 990)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 991
# ...
# Total params: 238,712,031
# ...

# %%
model.plot_history()

# %%
model.plot_matrix()

# %%
model.plot_matrix(normalize=True)
